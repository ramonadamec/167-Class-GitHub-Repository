# %% [markdown]
# <a href="https://colab.research.google.com/github/ramonadamec/167-Class-GitHub-Repository/blob/main/CSCI_167_Notebook_8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-pmz6r86f
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-pmz6r86f
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=4c5fe97df7d1002e19d9a9ef12c02bc660c2aee66d83f04b46177545fdac770a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pxvzgoje/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# #My Response
#
# 1. I think the training error to become zero at around 55 hidden units.
#
# 2. I expect the first minima of the double descent curve to appear at around 20 hidden units.
#
# 3. I expect the maximum of the double descent curve to appear at around 45 hidden units.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302452, train error 89.75,  test loss 2.302154, test error 89.70
# Epoch   100, train loss 1.910020, train error 72.22,  test loss 1.763121, test error 69.93
# Epoch   200, train loss 1.901080, train error 72.05,  test loss 1.743722, test error 69.45
# Epoch   300, train loss 1.899452, train error 72.30,  test loss 1.734208, test error 70.32
# Epoch   400, train loss 1.898798, train error 72.78,  test loss 1.731945, test error 69.72
# Epoch   500, train loss 1.898009, train error 71.40,  test loss 1.736029, test error 69.62
# Epoch   600, train loss 1.898001, train error 72.22,  test loss 1.730452, test error 69.38
# Epoch   700, train loss 1.902642, train error 71.05,  test loss 1.747230, test error 68.60
# Epoch   800, train loss 1.899553, train error 72.38,  test loss 1.725304, test error 70.15
# Epoch   900, train loss 1.897599, train error 70.97,  test loss 1.740519, test error 69.15
# Training model with   4 hidden variables
# Epoch     0, train loss 2.255656, train error 87.53,  test loss 2.250227, test error 87.22
# Epoch   100, train loss 1.734542, train error 62.15,  test loss 1.541201, test error 58.38
# Epoch   200, train loss 1.714348, train error 61.90,  test loss 1.516780, test error 58.42
# Epoch   300, train loss 1.710497, train error 61.58,  test loss 1.502693, test error 57.22
# Epoch   400, train loss 1.710985, train error 61.80,  test loss 1.506711, test error 58.22
# Epoch   500, train loss 1.709424, train error 62.03,  test loss 1.503341, test error 57.75
# Epoch   600, train loss 1.709833, train error 61.88,  test loss 1.507087, test error 58.92
# Epoch   700, train loss 1.710456, train error 61.80,  test loss 1.509246, test error 58.25
# Epoch   800, train loss 1.711699, train error 62.00,  test loss 1.502083, test error 58.20
# Epoch   900, train loss 1.708550, train error 62.12,  test loss 1.498431, test error 57.62
# Training model with   6 hidden variables
# Epoch     0, train loss 2.298690, train error 88.40,  test loss 2.300759, test error 88.68
# Epoch   100, train loss 1.685367, train error 60.30,  test loss 1.545397, test error 58.35
# Epoch   200, train loss 1.609734, train error 56.55,  test loss 1.450740, test error 54.45
# Epoch   300, train loss 1.588099, train error 55.03,  test loss 1.434514, test error 54.00
# Epoch   400, train loss 1.585189, train error 55.33,  test loss 1.439097, test error 54.83
# Epoch   500, train loss 1.579971, train error 55.25,  test loss 1.440571, test error 54.45
# Epoch   600, train loss 1.573798, train error 55.35,  test loss 1.436230, test error 54.72
# Epoch   700, train loss 1.584994, train error 56.05,  test loss 1.449556, test error 54.90
# Epoch   800, train loss 1.571875, train error 55.28,  test loss 1.444720, test error 54.80
# Epoch   900, train loss 1.574291, train error 55.28,  test loss 1.431287, test error 54.55
# Training model with   8 hidden variables
# Epoch     0, train loss 2.303292, train error 86.72,  test loss 2.311708, test error 87.05
# Epoch   100, train loss 1.571871, train error 55.38,  test loss 1.414278, test error 53.72
# Epoch   200, train loss 1.523964, train error 52.47,  test loss 1.381462, test error 50.92
# Epoch   300, train loss 1.463478, train error 49.50,  test loss 1.305232, test error 47.22
# Epoch   400, train loss 1.452360, train error 49.15,  test loss 1.312553, test error 48.15
# Epoch   500, train loss 1.451792, train error 48.75,  test loss 1.314362, test error 47.67
# Epoch   600, train loss 1.444783, train error 49.38,  test loss 1.319039, test error 48.42
# Epoch   700, train loss 1.432961, train error 49.40,  test loss 1.328928, test error 48.42
# Epoch   800, train loss 1.433861, train error 49.08,  test loss 1.335159, test error 48.38
# Epoch   900, train loss 1.433348, train error 49.12,  test loss 1.336863, test error 48.15
# Training model with  10 hidden variables
# Epoch     0, train loss 2.194269, train error 79.40,  test loss 2.168797, test error 78.15
# Epoch   100, train loss 1.541524, train error 53.25,  test loss 1.407213, test error 52.85
# Epoch   200, train loss 1.467584, train error 50.58,  test loss 1.333698, test error 49.22
# Epoch   300, train loss 1.440476, train error 49.22,  test loss 1.319907, test error 49.88
# Epoch   400, train loss 1.414557, train error 48.12,  test loss 1.307900, test error 47.58
# Epoch   500, train loss 1.402241, train error 47.85,  test loss 1.319023, test error 48.60
# Epoch   600, train loss 1.399558, train error 48.03,  test loss 1.336296, test error 48.55
# Epoch   700, train loss 1.392065, train error 47.95,  test loss 1.352085, test error 48.83
# Epoch   800, train loss 1.385827, train error 47.65,  test loss 1.349679, test error 48.70
# Epoch   900, train loss 1.384836, train error 47.72,  test loss 1.375175, test error 49.75
# Training model with  14 hidden variables
# Epoch     0, train loss 2.267916, train error 85.88,  test loss 2.254776, test error 85.03
# Epoch   100, train loss 1.440888, train error 49.65,  test loss 1.352516, test error 51.38
# Epoch   200, train loss 1.364124, train error 45.92,  test loss 1.335845, test error 50.65
# Epoch   300, train loss 1.335413, train error 45.80,  test loss 1.338973, test error 50.35
# Epoch   400, train loss 1.318140, train error 45.40,  test loss 1.355237, test error 50.53
# Epoch   500, train loss 1.296442, train error 44.90,  test loss 1.370335, test error 50.88
# Epoch   600, train loss 1.287060, train error 44.28,  test loss 1.388467, test error 51.08
# Epoch   700, train loss 1.279706, train error 44.35,  test loss 1.397780, test error 51.35
# Epoch   800, train loss 1.277914, train error 43.85,  test loss 1.417214, test error 51.60
# Epoch   900, train loss 1.286117, train error 44.22,  test loss 1.433039, test error 51.35
# Training model with  18 hidden variables
# Epoch     0, train loss 2.160982, train error 80.05,  test loss 2.109000, test error 77.57
# Epoch   100, train loss 1.338713, train error 45.17,  test loss 1.315503, test error 48.72
# Epoch   200, train loss 1.266366, train error 43.22,  test loss 1.362818, test error 50.72
# Epoch   300, train loss 1.214864, train error 40.95,  test loss 1.366297, test error 49.88
# Epoch   400, train loss 1.193300, train error 40.50,  test loss 1.400582, test error 51.05
# Epoch   500, train loss 1.181023, train error 39.58,  test loss 1.433079, test error 51.00
# Epoch   600, train loss 1.151850, train error 39.72,  test loss 1.434598, test error 50.75
# Epoch   700, train loss 1.142880, train error 38.70,  test loss 1.458640, test error 50.67
# Epoch   800, train loss 1.133736, train error 39.15,  test loss 1.499915, test error 51.47
# Epoch   900, train loss 1.126174, train error 38.33,  test loss 1.499113, test error 50.33
# Training model with  22 hidden variables
# Epoch     0, train loss 2.186426, train error 80.88,  test loss 2.159139, test error 79.88
# Epoch   100, train loss 1.294330, train error 43.28,  test loss 1.324065, test error 48.92
# Epoch   200, train loss 1.160239, train error 38.75,  test loss 1.344447, test error 48.62
# Epoch   300, train loss 1.101723, train error 37.22,  test loss 1.407079, test error 49.42
# Epoch   400, train loss 1.069432, train error 35.45,  test loss 1.457479, test error 50.42
# Epoch   500, train loss 1.052701, train error 35.38,  test loss 1.500602, test error 50.17
# Epoch   600, train loss 1.037154, train error 35.45,  test loss 1.557463, test error 50.67
# Epoch   700, train loss 1.016609, train error 34.05,  test loss 1.595502, test error 51.60
# Epoch   800, train loss 1.005354, train error 34.07,  test loss 1.627518, test error 51.53
# Epoch   900, train loss 0.985200, train error 32.85,  test loss 1.674791, test error 52.60
# Training model with  26 hidden variables
# Epoch     0, train loss 2.082893, train error 78.85,  test loss 2.039689, test error 77.95
# Epoch   100, train loss 1.210302, train error 40.75,  test loss 1.390794, test error 49.58
# Epoch   200, train loss 1.045962, train error 35.45,  test loss 1.480859, test error 50.92
# Epoch   300, train loss 0.973696, train error 32.88,  test loss 1.609919, test error 51.70
# Epoch   400, train loss 0.938749, train error 31.95,  test loss 1.703481, test error 52.22
# Epoch   500, train loss 0.907365, train error 31.05,  test loss 1.765286, test error 51.92
# Epoch   600, train loss 0.875331, train error 29.60,  test loss 1.889447, test error 52.92
# Epoch   700, train loss 0.863447, train error 29.22,  test loss 1.911341, test error 52.38
# Epoch   800, train loss 0.846117, train error 28.60,  test loss 1.986507, test error 53.50
# Epoch   900, train loss 0.848051, train error 30.03,  test loss 2.055647, test error 53.85
# Training model with  30 hidden variables
# Epoch     0, train loss 2.105567, train error 79.05,  test loss 2.045243, test error 77.65
# Epoch   100, train loss 1.096605, train error 34.40,  test loss 1.291299, test error 47.28
# Epoch   200, train loss 0.910762, train error 29.30,  test loss 1.459112, test error 49.75
# Epoch   300, train loss 0.842772, train error 27.80,  test loss 1.651377, test error 51.08
# Epoch   400, train loss 0.773692, train error 25.45,  test loss 1.813025, test error 51.85
# Epoch   500, train loss 0.742801, train error 24.32,  test loss 1.985196, test error 52.60
# Epoch   600, train loss 0.700914, train error 22.72,  test loss 2.123094, test error 53.70
# Epoch   700, train loss 0.712173, train error 23.97,  test loss 2.237051, test error 53.30
# Epoch   800, train loss 0.662964, train error 21.75,  test loss 2.319574, test error 53.38
# Epoch   900, train loss 0.666747, train error 22.53,  test loss 2.457237, test error 54.22
# Training model with  35 hidden variables
# Epoch     0, train loss 2.130613, train error 79.10,  test loss 2.097759, test error 77.72
# Epoch   100, train loss 1.010396, train error 33.03,  test loss 1.386752, test error 48.95
# Epoch   200, train loss 0.778304, train error 25.45,  test loss 1.755625, test error 50.72
# Epoch   300, train loss 0.658146, train error 21.55,  test loss 2.091360, test error 52.08
# Epoch   400, train loss 0.593889, train error 19.78,  test loss 2.552898, test error 54.35
# Epoch   500, train loss 0.545136, train error 17.53,  test loss 2.951371, test error 54.90
# Epoch   600, train loss 0.491372, train error 15.82,  test loss 3.264202, test error 54.70
# Epoch   700, train loss 0.521116, train error 18.22,  test loss 3.681442, test error 55.05
# Epoch   800, train loss 0.458472, train error 15.65,  test loss 3.893349, test error 55.75
# Epoch   900, train loss 0.449885, train error 15.45,  test loss 4.180604, test error 55.83
# Training model with  40 hidden variables
# Epoch     0, train loss 2.127530, train error 78.90,  test loss 2.098074, test error 79.78
# Epoch   100, train loss 0.920154, train error 29.43,  test loss 1.463580, test error 49.60
# Epoch   200, train loss 0.661081, train error 21.62,  test loss 1.921968, test error 52.83
# Epoch   300, train loss 0.489265, train error 15.22,  test loss 2.553748, test error 54.75
# Epoch   400, train loss 0.401697, train error 12.22,  test loss 3.228281, test error 56.17
# Epoch   500, train loss 0.378247, train error 12.05,  test loss 3.906949, test error 57.12
# Epoch   600, train loss 0.318177, train error 11.07,  test loss 4.591251, test error 57.10
# Epoch   700, train loss 0.300416, train error 10.15,  test loss 5.183897, test error 56.60
# Epoch   800, train loss 0.279751, train error 9.43,  test loss 5.885741, test error 56.58
# Epoch   900, train loss 0.252763, train error 9.03,  test loss 6.580523, test error 57.30
# Training model with  45 hidden variables
# Epoch     0, train loss 2.161392, train error 79.55,  test loss 2.164489, test error 80.78
# Epoch   100, train loss 0.803206, train error 24.65,  test loss 1.466085, test error 48.65
# Epoch   200, train loss 0.475244, train error 14.45,  test loss 2.121519, test error 51.30
# Epoch   300, train loss 0.343941, train error 11.18,  test loss 3.047280, test error 52.25
# Epoch   400, train loss 0.241375, train error 7.53,  test loss 4.110152, test error 54.03
# Epoch   500, train loss 0.201317, train error 6.95,  test loss 5.308009, test error 54.72
# Epoch   600, train loss 0.158024, train error 5.40,  test loss 6.327421, test error 55.47
# Epoch   700, train loss 0.113873, train error 3.85,  test loss 7.240726, test error 55.92
# Epoch   800, train loss 0.009632, train error 0.00,  test loss 8.345632, test error 56.03
# Epoch   900, train loss 0.005847, train error 0.00,  test loss 8.922205, test error 55.95
# Training model with  50 hidden variables
# Epoch     0, train loss 2.079780, train error 75.82,  test loss 2.035432, test error 77.57
# Epoch   100, train loss 0.722472, train error 22.50,  test loss 1.624905, test error 51.78
# Epoch   200, train loss 0.355580, train error 10.47,  test loss 2.776716, test error 55.88
# Epoch   300, train loss 0.154976, train error 4.18,  test loss 4.553481, test error 57.47
# Epoch   400, train loss 0.028204, train error 0.00,  test loss 6.257503, test error 57.80
# Epoch   500, train loss 0.012825, train error 0.00,  test loss 7.238425, test error 57.50
# Epoch   600, train loss 0.008197, train error 0.00,  test loss 7.907506, test error 57.47
# Epoch   700, train loss 0.005855, train error 0.00,  test loss 8.393003, test error 57.50
# Epoch   800, train loss 0.004505, train error 0.00,  test loss 8.791326, test error 57.75
# Epoch   900, train loss 0.003646, train error 0.00,  test loss 9.115788, test error 57.60
# Training model with  55 hidden variables
# Epoch     0, train loss 2.051016, train error 76.70,  test loss 1.973468, test error 75.47
# Epoch   100, train loss 0.639540, train error 20.20,  test loss 1.701845, test error 52.17
# Epoch   200, train loss 0.191081, train error 4.53,  test loss 3.127943, test error 53.55
# Epoch   300, train loss 0.031733, train error 0.00,  test loss 4.815633, test error 54.62
# Epoch   400, train loss 0.012502, train error 0.00,  test loss 5.712836, test error 54.55
# Epoch   500, train loss 0.007510, train error 0.00,  test loss 6.271234, test error 54.67
# Epoch   600, train loss 0.005221, train error 0.00,  test loss 6.677936, test error 54.67
# Epoch   700, train loss 0.003953, train error 0.00,  test loss 6.993149, test error 54.67
# Epoch   800, train loss 0.003156, train error 0.00,  test loss 7.255846, test error 54.70
# Epoch   900, train loss 0.002611, train error 0.00,  test loss 7.479451, test error 54.70
# Training model with  60 hidden variables
# Epoch     0, train loss 2.075045, train error 77.60,  test loss 2.010412, test error 76.80
# Epoch   100, train loss 0.539922, train error 16.05,  test loss 1.772782, test error 52.00
# Epoch   200, train loss 0.102987, train error 0.97,  test loss 3.543277, test error 54.80
# Epoch   300, train loss 0.018774, train error 0.00,  test loss 4.869892, test error 54.53
# Epoch   400, train loss 0.009139, train error 0.00,  test loss 5.551105, test error 54.40
# Epoch   500, train loss 0.005761, train error 0.00,  test loss 5.996742, test error 54.33
# Epoch   600, train loss 0.004128, train error 0.00,  test loss 6.331897, test error 54.35
# Epoch   700, train loss 0.003181, train error 0.00,  test loss 6.602673, test error 54.45
# Epoch   800, train loss 0.002546, train error 0.00,  test loss 6.820528, test error 54.40
# Epoch   900, train loss 0.002118, train error 0.00,  test loss 7.007863, test error 54.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.031051, train error 75.55,  test loss 1.969311, test error 74.53
# Epoch   100, train loss 0.345206, train error 8.28,  test loss 1.951126, test error 51.28
# Epoch   200, train loss 0.030005, train error 0.00,  test loss 3.510704, test error 52.95
# Epoch   300, train loss 0.010391, train error 0.00,  test loss 4.246331, test error 53.20
# Epoch   400, train loss 0.005875, train error 0.00,  test loss 4.663581, test error 53.20
# Epoch   500, train loss 0.003978, train error 0.00,  test loss 4.954844, test error 53.25
# Epoch   600, train loss 0.002961, train error 0.00,  test loss 5.180439, test error 53.42
# Epoch   700, train loss 0.002324, train error 0.00,  test loss 5.358844, test error 53.47
# Epoch   800, train loss 0.001900, train error 0.00,  test loss 5.508647, test error 53.40
# Epoch   900, train loss 0.001599, train error 0.00,  test loss 5.637110, test error 53.42
# Training model with  80 hidden variables
# Epoch     0, train loss 2.008787, train error 73.85,  test loss 1.951350, test error 73.93
# Epoch   100, train loss 0.240286, train error 4.88,  test loss 2.094383, test error 51.17
# Epoch   200, train loss 0.019215, train error 0.00,  test loss 3.432340, test error 51.62
# Epoch   300, train loss 0.007684, train error 0.00,  test loss 3.977065, test error 51.88
# Epoch   400, train loss 0.004566, train error 0.00,  test loss 4.300739, test error 51.95
# Epoch   500, train loss 0.003152, train error 0.00,  test loss 4.528658, test error 51.95
# Epoch   600, train loss 0.002371, train error 0.00,  test loss 4.702914, test error 51.72
# Epoch   700, train loss 0.001884, train error 0.00,  test loss 4.846777, test error 51.97
# Epoch   800, train loss 0.001552, train error 0.00,  test loss 4.966795, test error 52.08
# Epoch   900, train loss 0.001314, train error 0.00,  test loss 5.071082, test error 51.97
# Training model with  90 hidden variables
# Epoch     0, train loss 1.990322, train error 74.32,  test loss 1.916709, test error 75.28
# Epoch   100, train loss 0.141433, train error 1.20,  test loss 2.158200, test error 51.42
# Epoch   200, train loss 0.014616, train error 0.00,  test loss 3.193991, test error 52.55
# Epoch   300, train loss 0.006485, train error 0.00,  test loss 3.612049, test error 52.67
# Epoch   400, train loss 0.003965, train error 0.00,  test loss 3.863908, test error 52.62
# Epoch   500, train loss 0.002789, train error 0.00,  test loss 4.051279, test error 52.60
# Epoch   600, train loss 0.002120, train error 0.00,  test loss 4.194877, test error 52.62
# Epoch   700, train loss 0.001695, train error 0.00,  test loss 4.314799, test error 52.53
# Epoch   800, train loss 0.001405, train error 0.00,  test loss 4.415956, test error 52.50
# Epoch   900, train loss 0.001195, train error 0.00,  test loss 4.502606, test error 52.38
# Training model with 100 hidden variables
# Epoch     0, train loss 1.990554, train error 73.75,  test loss 1.939159, test error 73.97
# Epoch   100, train loss 0.115645, train error 0.75,  test loss 2.235954, test error 51.50
# Epoch   200, train loss 0.012877, train error 0.00,  test loss 3.136151, test error 51.72
# Epoch   300, train loss 0.005866, train error 0.00,  test loss 3.515855, test error 51.42
# Epoch   400, train loss 0.003642, train error 0.00,  test loss 3.748353, test error 51.53
# Epoch   500, train loss 0.002577, train error 0.00,  test loss 3.923995, test error 51.50
# Epoch   600, train loss 0.001967, train error 0.00,  test loss 4.057768, test error 51.62
# Epoch   700, train loss 0.001578, train error 0.00,  test loss 4.167575, test error 51.65
# Epoch   800, train loss 0.001310, train error 0.00,  test loss 4.262817, test error 51.70
# Epoch   900, train loss 0.001114, train error 0.00,  test loss 4.343616, test error 51.65
# Training model with 120 hidden variables
# Epoch     0, train loss 1.956391, train error 72.28,  test loss 1.903913, test error 73.70
# Epoch   100, train loss 0.050113, train error 0.00,  test loss 2.155482, test error 49.20
# Epoch   200, train loss 0.009381, train error 0.00,  test loss 2.735666, test error 49.08
# Epoch   300, train loss 0.004642, train error 0.00,  test loss 2.999851, test error 49.05
# Epoch   400, train loss 0.002968, train error 0.00,  test loss 3.169896, test error 48.92
# Epoch   500, train loss 0.002142, train error 0.00,  test loss 3.299125, test error 49.00
# Epoch   600, train loss 0.001654, train error 0.00,  test loss 3.397477, test error 48.95
# Epoch   700, train loss 0.001338, train error 0.00,  test loss 3.481539, test error 48.95
# Epoch   800, train loss 0.001117, train error 0.00,  test loss 3.552311, test error 48.97
# Epoch   900, train loss 0.000955, train error 0.00,  test loss 3.613689, test error 49.00
# Training model with 140 hidden variables
# Epoch     0, train loss 1.955191, train error 71.50,  test loss 1.892433, test error 71.97
# Epoch   100, train loss 0.036442, train error 0.00,  test loss 2.177953, test error 49.58
# Epoch   200, train loss 0.008054, train error 0.00,  test loss 2.664351, test error 49.40
# Epoch   300, train loss 0.004126, train error 0.00,  test loss 2.896150, test error 49.30
# Epoch   400, train loss 0.002673, train error 0.00,  test loss 3.049746, test error 49.53
# Epoch   500, train loss 0.001944, train error 0.00,  test loss 3.162602, test error 49.42
# Epoch   600, train loss 0.001509, train error 0.00,  test loss 3.252346, test error 49.42
# Epoch   700, train loss 0.001225, train error 0.00,  test loss 3.327229, test error 49.42
# Epoch   800, train loss 0.001026, train error 0.00,  test loss 3.390445, test error 49.38
# Epoch   900, train loss 0.000879, train error 0.00,  test loss 3.446126, test error 49.35
# Training model with 160 hidden variables
# Epoch     0, train loss 1.971244, train error 74.95,  test loss 1.898353, test error 75.25
# Epoch   100, train loss 0.029323, train error 0.00,  test loss 2.196346, test error 50.08
# Epoch   200, train loss 0.007253, train error 0.00,  test loss 2.627904, test error 50.33
# Epoch   300, train loss 0.003814, train error 0.00,  test loss 2.837206, test error 50.22
# Epoch   400, train loss 0.002505, train error 0.00,  test loss 2.975402, test error 50.33
# Epoch   500, train loss 0.001835, train error 0.00,  test loss 3.078789, test error 50.20
# Epoch   600, train loss 0.001432, train error 0.00,  test loss 3.162153, test error 50.38
# Epoch   700, train loss 0.001166, train error 0.00,  test loss 3.231122, test error 50.45
# Epoch   800, train loss 0.000979, train error 0.00,  test loss 3.289487, test error 50.25
# Epoch   900, train loss 0.000840, train error 0.00,  test loss 3.340714, test error 50.25
# Training model with 180 hidden variables
# Epoch     0, train loss 1.920813, train error 70.50,  test loss 1.833070, test error 70.70
# Epoch   100, train loss 0.024064, train error 0.00,  test loss 2.011054, test error 48.42
# Epoch   200, train loss 0.006583, train error 0.00,  test loss 2.350498, test error 48.35
# Epoch   300, train loss 0.003525, train error 0.00,  test loss 2.524503, test error 48.45
# Epoch   400, train loss 0.002339, train error 0.00,  test loss 2.637685, test error 48.35
# Epoch   500, train loss 0.001722, train error 0.00,  test loss 2.724416, test error 48.53
# Epoch   600, train loss 0.001348, train error 0.00,  test loss 2.793458, test error 48.60
# Epoch   700, train loss 0.001101, train error 0.00,  test loss 2.851245, test error 48.55
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 2.901137, test error 48.60
# Epoch   900, train loss 0.000796, train error 0.00,  test loss 2.945088, test error 48.55
# Training model with 200 hidden variables
# Epoch     0, train loss 1.921359, train error 71.07,  test loss 1.838262, test error 70.65
# Epoch   100, train loss 0.021790, train error 0.00,  test loss 1.959434, test error 48.08
# Epoch   200, train loss 0.006167, train error 0.00,  test loss 2.264430, test error 48.03
# Epoch   300, train loss 0.003340, train error 0.00,  test loss 2.419141, test error 48.05
# Epoch   400, train loss 0.002226, train error 0.00,  test loss 2.524109, test error 48.10
# Epoch   500, train loss 0.001644, train error 0.00,  test loss 2.602791, test error 47.97
# Epoch   600, train loss 0.001291, train error 0.00,  test loss 2.666883, test error 48.10
# Epoch   700, train loss 0.001056, train error 0.00,  test loss 2.719859, test error 47.95
# Epoch   800, train loss 0.000889, train error 0.00,  test loss 2.764512, test error 47.90
# Epoch   900, train loss 0.000765, train error 0.00,  test loss 2.803676, test error 47.88
# Training model with 250 hidden variables
# Epoch     0, train loss 1.898786, train error 70.28,  test loss 1.808007, test error 71.18
# Epoch   100, train loss 0.017405, train error 0.00,  test loss 1.882889, test error 47.05
# Epoch   200, train loss 0.005437, train error 0.00,  test loss 2.136126, test error 47.17
# Epoch   300, train loss 0.003021, train error 0.00,  test loss 2.266505, test error 46.72
# Epoch   400, train loss 0.002037, train error 0.00,  test loss 2.356658, test error 46.97
# Epoch   500, train loss 0.001514, train error 0.00,  test loss 2.423462, test error 47.08
# Epoch   600, train loss 0.001195, train error 0.00,  test loss 2.478007, test error 47.08
# Epoch   700, train loss 0.000980, train error 0.00,  test loss 2.524285, test error 47.10
# Epoch   800, train loss 0.000827, train error 0.00,  test loss 2.563659, test error 47.00
# Epoch   900, train loss 0.000714, train error 0.00,  test loss 2.598455, test error 47.00
# Training model with 300 hidden variables
# Epoch     0, train loss 1.873378, train error 67.47,  test loss 1.797737, test error 68.70
# Epoch   100, train loss 0.014272, train error 0.00,  test loss 1.792351, test error 45.65
# Epoch   200, train loss 0.004753, train error 0.00,  test loss 2.000713, test error 45.35
# Epoch   300, train loss 0.002694, train error 0.00,  test loss 2.113634, test error 45.22
# Epoch   400, train loss 0.001835, train error 0.00,  test loss 2.190442, test error 45.28
# Epoch   500, train loss 0.001373, train error 0.00,  test loss 2.250601, test error 45.35
# Epoch   600, train loss 0.001088, train error 0.00,  test loss 2.298330, test error 45.25
# Epoch   700, train loss 0.000896, train error 0.00,  test loss 2.338401, test error 45.20
# Epoch   800, train loss 0.000758, train error 0.00,  test loss 2.373172, test error 45.20
# Epoch   900, train loss 0.000655, train error 0.00,  test loss 2.403692, test error 45.22
# Training model with 400 hidden variables
# Epoch     0, train loss 1.866390, train error 67.80,  test loss 1.801341, test error 70.28
# Epoch   100, train loss 0.011525, train error 0.00,  test loss 1.772053, test error 45.90
# Epoch   200, train loss 0.004113, train error 0.00,  test loss 1.939695, test error 45.75
# Epoch   300, train loss 0.002382, train error 0.00,  test loss 2.035323, test error 45.58
# Epoch   400, train loss 0.001642, train error 0.00,  test loss 2.102965, test error 45.60
# Epoch   500, train loss 0.001238, train error 0.00,  test loss 2.154491, test error 45.47
# Epoch   600, train loss 0.000987, train error 0.00,  test loss 2.196379, test error 45.38
# Epoch   700, train loss 0.000815, train error 0.00,  test loss 2.231570, test error 45.42
# Epoch   800, train loss 0.000692, train error 0.00,  test loss 2.262038, test error 45.45
# Epoch   900, train loss 0.000600, train error 0.00,  test loss 2.288743, test error 45.40

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
